# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('./Files/Metagame.xls', sheetname='Sheet1')
df.fillna(value=0, inplace=True)
Y = df['Total:'][1:]
X = df['Loja:'][1:]
df.head()
# Out:
#                Loja:  Duelos  Gargula  Hobbits  Arena Porto  Playerspot  \
# 0         Jogadores:    40.0     56.0     32.0         32.0        40.0
# 1     Death's Shadow     6.0      6.0      2.0          6.0         3.0
# 2               Burn     3.0      7.0      2.0          2.0         6.0
# 3  Colorless Eldrazi     4.0      4.0      4.0          2.0         2.0
# 4         TitanShift     2.0      3.0      2.0          5.0         4.0
#
#    Guardian Porto  Versus  Drawstep  Magus  Lotus  Total:  Média:  \
# 0            39.0   107.0      16.0   25.0   41.0     428    42.8
# 1             6.0    12.0       2.0    0.0    2.0      45     4.5
# 2             3.0    10.0       3.0    1.0    3.0      40     4.0
# 3             0.0     6.0       1.0    1.0    4.0      28     2.8
# 4             3.0     6.0       0.0    0.0    3.0      28     2.8
#
#    Percentagem:
# 0    100.000000
# 1     10.514019
# 2      9.345794
# 3      6.542056
# 4      6.542056

# %%
fig1, ax1 = plt.subplots(figsize=(12,12))
ax1.pie(Y, labels=X, autopct='%1.1f%%',
        shadow=True, startangle=-170, pctdistance=0.9)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
