# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## The Lotus Market

# %%
df = pd.read_excel('./Files/Season_1_2017-2018.xlsx', sheetname='LotusMarket', header=None, names=['Deck', ''])

# %%
df.head()
# Out:
#                 Deck
# 0  Colorless Eldrazi  4
# 1           Affinity  3
# 2         Titanshift  3
# 3               Burn  3
# 4   Counters Company  3

# %%
def absolute_value(val):
    a  = np.round(val/100.*df[''].sum(), 0)
    return a

# %%
df.plot.pie(y='', labels=df['Deck'], figsize=(8,8), legend=None, fontsize=16)
plt.show()

# %%
df.plot.bar(y='', figsize=(16,8), fontsize=16, x=df['Deck'])
plt.show()
